# %% [markdown]
# # Project: Channel Video Uploads Sorted by Length

# %%
## Only needs to be done once, then comment it out after.
# !pip install --upgrade google-api-python-client
# !pip install isodate

from googleapiclient.discovery import build
import pandas as pd
from IPython.display import display
import isodate

# %%
api_key = ''
channel_id = "UC8butISFwT-Wl7EV0hUK0BQ"
playlist_id = "UU8butISFwT-Wl7EV0hUK0BQ"

# Provided by YouTube v3 Channel list documentation.

api_service_name = "youtube"
api_version = "v3"

# Create an API client
youtube = build(api_service_name, api_version, developerKey = api_key)

# %%
search_term = "backend"

# %% [markdown]
# # Test run data for a couple videos

# %%
request = youtube.search().list(
        part = "snippet",
        channelId = "UC8butISFwT-Wl7EV0hUK0BQ",
        maxResults = 50,
        type = "video",
        q = "backend"
)

response = request.execute()

display(response)

# %% [markdown]
# # Get all the video ids

# %%
def get_video_ids():
    
    # List to hold our video ids.
    video_ids = []

    request = youtube.search().list(
        part = "snippet",
        channelId = channel_id,
        maxResults = 50,
        type = "video",
        q = search_term
    )

    response = request.execute()

    # Populate our video ids list.
    for item in response['items']:
        video_ids.append(item['id']['videoId'])
       
    # Since we want all the videos, not just one page's worth, we have to
    # iterate over each new page.
    next_page_token = response.get('nextPageToken')
    
    while next_page_token is not None:
        request = youtube.search().list(
            part = "snippet",
            channelId = channel_id,
            maxResults = 50,
            type = "video",
            q = search_term,
            pageToken = next_page_token
        )

        response = request.execute()
        
        for item in response['items']:
            video_ids.append(item['id']['videoId'])
            
        next_page_token = response.get('nextPageToken')
    
    return video_ids

# %%
video_ids = get_video_ids()

len(video_ids)

# %% [markdown]
# # Get details for all the video ids

# %%
def get_video_details(youtube, video_ids):
    
    all_video_info = []
    
    for i in range(0, len(video_ids), 50):
        request = youtube.videos().list(
            part = "snippet,contentDetails",
            id = ",".join(video_ids[i : i + 50])
        )
        
        response = request.execute()
        
        for video in response['items']:
            stats_to_keep = {'snippet': ['title', 'description', 'publishedAt'],
                             'contentDetails': ['duration']
                            }
            video_info = {}
            video_info['video_id'] = video['id']
            
            for k in stats_to_keep.keys():
                for v in stats_to_keep[k]:
                    try:
                        video_info[v] = video[k][v]
                    except:
                        video_info[v] = None
            
            all_video_info.append(video_info)
            
    return pd.DataFrame(all_video_info)

# %%
video_df = get_video_details(youtube, video_ids)

video_df

# %%
# Convert duration column to standard hours, minutes, seconds format.

video_df['duration_time'] = video_df['duration'].apply(lambda x: isodate.parse_duration(x))
video_df['duration_seconds'] = video_df['duration'].apply(lambda x: isodate.parse_duration(x).total_seconds())
video_df['duration_time'] = video_df['duration_time'].astype('timedelta64[s]')

video_df

# %%
# Sort the videos by the durationTime column to find the shortest videos.

video_df.sort_values(by = 'duration_time', ascending = True).head(50)
# Out:
#         video_id                                              title  \
# 53   SIj4pzF0uk8  A Day in the Life of freeCodeCamp U.S. Staff (...
# 23   YY2ZhUQZyE4                                Why Node and React?
# 433  8IOHjh3VQMU         Webhooks Explained with a Roadtrip #shorts
# 202  j3YM5eUjw0E                                   100 Days of Code
# 301  JQ_BCly-heU        Computer Basics 20: What Do Programmers Do?
# 255  5ZzioWgcObg                  Web Design: Development vs Design
# 158  WvXsY736Kz0          What do computer programmers actually do?
# 73   ABlaMXkUwzY     Debugging JavaScript - Are you doing it wrong?
# 329  PfLBugPdgSk                    Learn to Code: 5 Secret Weapons
# 318  VRz0nbax0uI  20 String Methods in 7 Minutes - Beau teaches ...
# 347  SzugBxKJbyw  What it's like to freelance in Nigeria - A Day...
# 328  AKacS-t-MfQ   Day in the life of a freelance developer and mom
# 353  oKoXcm5f29o                          Planning - Code Vlog {03}
# 426  XzADFUpAitc    Recipe Box Routing and Storage - Code Vlog {21}
# 401  YbV6OXvR8eI             Recipe Box Components - Code Vlog {20}
# 368  YbV6OXvR8eI             Recipe Box Components - Code Vlog {20}
# 142  VqiEhZYmvKk  Which programming language should you learn fi...
# 13   9He4UBLyk8Y                   Front End Developer Roadmap 2024
# 406  mu3epeXRIt0       A day at Pennybox with Co-Founder Reji Eapen
# 363  mu3epeXRIt0       A day at Pennybox with Co-Founder Reji Eapen
# 257  yrIvUFDPR0g  Interview Tips from a Senior Software Engineer...
# 338  F1VZj-zqnG4                  Debugging Node.js with Paul Irish
# 360  Y0-qdp-XBJg       Protected Routes in React using React Router
# 375  d-PZ78KDeag                  Logic for Programmers: Set Theory
# 339  m7ZYJkvWwlE  Google Interview Question: How to Code a Queue...
# 270  xe1yllE3mFE  Alex Kurilin on Understanding the Tradeoffs of...
# 299  1EUwWiED1II  The Future is Serverless: What That Means for ...
# 216  qTE48ByxZX4           Web Workers —  Outsource your JavaScript
# 388  AQe1INHTlkc                             The Cost Of JavaScript
# 409  AQe1INHTlkc                             The Cost Of JavaScript
# 239  9MOZ7-CvJew  Pushing the Limits of Kubernetes with Game of ...
# 229  iYwF2qXBt4c                   Getting Your First Developer Job
# 273  5mx7wRs8ju4                 WebAssembly: The What, Why and How
# 365  BK9iHnkr9nM  Setting up MailChimp on WordPress with plugins...
# 286  _AaJmzmxHyg       How to boost your web development efficiency
# 384  _AaJmzmxHyg       How to boost your web development efficiency
# 196  A5GvnU1JxdQ    Build Better and Discoverable APIs with GraphQL
# 269  1BT4efG-ItA                  Introduction to Front End Testing
# 256  6iZAl0jCHGc     Everyone is a Developer - Talk by Jessica Lord
# 254  mZdznKc5ZaM  One weird trick to becoming a better software ...
# 230  NSts93C9UeE  JAMstack Tutorial - Full site using Netlify & ...
# 182  vXJpOHz3_sY  The All Powerful Front End Developer - Chris C...
# 419  fsCjFHuMXj0                     Build a Node.js API - tutorial
# 374  fsCjFHuMXj0                     Build a Node.js API - tutorial
# 240  MMg4n68wodo  All about GRAND Stack: GraphQL, React, Apollo,...
# 300  xPEMup5SPTM                          TypeScript 101 (tutorial)
# 324  UqMUoINlKnY                                DevOps Introduction
# 280  T6Yr7htcbk4  How not to become a senior developer (and what...
# 346  pTw7CDD6k2c      React: Initial Setup - Live Coding with Jesse
# 171  yfHHvmaMkcA  Vector Embeddings Tutorial – Code Your Own AI ...
#
#                                            description           publishedAt  \
# 280  PT35M11S 0 days 00:35:11            2111.0
# 346  PT36M15S 0 days 00:36:15            2175.0
# 171  PT36M23S 0 days 00:36:23            2183.0

# %%
# Create a copy of the DataFrame
filtered_video_df = video_df.copy()

# Filter DataFrame to keep rows where duration is greater than or equal to 25 minutes (1500 seconds)
filtered_video_df = filtered_video_df[filtered_video_df['duration_seconds'] >= 1500]

# Drop the 'duration_seconds' column if you no longer need it
filtered_video_df.drop(columns = ['duration_seconds'], inplace = True)

# %%
filtered_video_df.sort_values(by = 'duration_time', ascending = True).reset_index().iloc[0:60]
# Out:
#     index     video_id                                              title  \
# 0     196  A5GvnU1JxdQ    Build Better and Discoverable APIs with GraphQL
# 1     269  1BT4efG-ItA                  Introduction to Front End Testing
# 2     256  6iZAl0jCHGc     Everyone is a Developer - Talk by Jessica Lord
# 3     254  mZdznKc5ZaM  One weird trick to becoming a better software ...
# 4     230  NSts93C9UeE  JAMstack Tutorial - Full site using Netlify & ...
# 5     182  vXJpOHz3_sY  The All Powerful Front End Developer - Chris C...
# 6     419  fsCjFHuMXj0                     Build a Node.js API - tutorial
# 7     374  fsCjFHuMXj0                     Build a Node.js API - tutorial
# 8     240  MMg4n68wodo  All about GRAND Stack: GraphQL, React, Apollo,...
# 9     300  xPEMup5SPTM                          TypeScript 101 (tutorial)
# 10    324  UqMUoINlKnY                                DevOps Introduction
# 11    280  T6Yr7htcbk4  How not to become a senior developer (and what...
# 12    346  pTw7CDD6k2c      React: Initial Setup - Live Coding with Jesse
# 13    171  yfHHvmaMkcA  Vector Embeddings Tutorial – Code Your Own AI ...
# 14    422  -FWuNnCe73g  Full stack Python Flask tutorial - Build a soc...
# 15    251  lo4BSraYvc8                          How to Become a Developer
# 16    310  Jppuj6M1sJ4                          React Router Crash Course
# 17    217  ywLxbDV9TBU  Create and Deploy Websites and IaC by Chatting...
# 18    429  hEj61QV0wdg                          The Art of Web API Design
# 19    228  2KkwRjuS30I  React Native with Hooks (P7D7) - Live Coding w...
# 20    243  ksVQ68wHR9c  Building Performance Optimized Web Apps with A...
# 21    351  xZMwg5z5VGk  Full Stack Web App using Vue.js & Express.js: ...
# 22    312  eT3CMbWMC7c  React: Production Server Setup - Live Coding w...
# 23    378  1rIP81hjs2U                   Live Workshop: Basics of ReactJS
# 24    410  1rIP81hjs2U                   Live Workshop: Basics of ReactJS
# 25    223  ifOzAyR1cG4        Vue.js & Firebase Tutorial - Real-time Chat
# 26     48  Z1RJmh_OqeA             Learn Flask for Python - Full Tutorial
# 27    379  jAAmI5gMlVo                  Async/Await - JavaScript Tutorial
# 28    225  GwHX6FM-BHw  Developer Career Questions ANSWERED (featuring...
# 29    316  lzelnAI914A  Passkey Authentication with Express.js and Doc...
# 30    245  a-JKj7m2LIo  Build a chat application like Slack - React / ...
# 31    337  RjBxeb9erQk                           Intro to Node.js and npm
# 32    143  9t9Mp0BGnyI                       NGINX Tutorial for Beginners
# 33    259  3zw5LgKDMhg  Full Stack Web App using Vue.js & Express.js: ...
# 34    192  gdZH7Anh_6w                                    Intro to Vue.js
# 35    218  hcHczN3wryw  Kubernetes: A Developer's Guide to Orchestrati...
# 36    145  VCayKl82Lt8  Learn Terraform with Google Cloud Platform – I...
# 37    330  RJ2kwpzX8so    Web App Testing with WebdriverIO - Crash Course
# 38    336  2cJya4h5ync  React: Parameterized Routing with Next.js - Li...
# 39    166  n8mNX2YqkUs  Learn JavaScript Interactively in NEW freeCode...
# 40    195  0ndQbJaw89Y                                   SSO for Web APIs
# 41    292  dT_VqBmXR2g  Live ReactJS Coding (P5D102) - Live Coding wit...
# 42    390  dT_VqBmXR2g  Live ReactJS Coding (P5D102) - Live Coding wit...
# 43    284  4AnhZ3o85LA  Setting Up KeystoneJS (P5D10) - Live Coding wi...
# 44    354  Z60S9J7TCeU  Amazon Alexa Skill Development Live Stream - D...
# 45    151  Fa4cRMaTDUI  Full Stack Web App using Vue.js & Express.js: ...
# 46     72  qjrkV4RjgIU  Web application security: 10 things developers...
# 47    127  JgwI22y_eFA  Build an Online Store Using AWS, React, and St...
# 48    369  Kzeog8yTFaE             A Brief History of Frontend Frameworks
# 49    211  Kzeog8yTFaE             A Brief History of Frontend Frameworks
# 50    405  JhAtZlhk97k  WordPress Plugin Editing  (P5D82) - Live Codin...
# 51    394  JhAtZlhk97k  WordPress Plugin Editing  (P5D82) - Live Codin...
# 52    253  j8heyfH8BAI  Amazon Alexa Skill Development Live Stream - D...
# 53    340  UjDpW_SOrlw  Code a Discord Chat Bot That Talks Like Your F...
# 54    219  XC2B_fE7S0g              How to Get Started in Web Development
# 55    252  dlK7jec2rXo  API Security for PCI Compliance (Data Security...
# 56    199  W_3wAsp0SUc  React Routing with Express (P5D62) - Live Codi...
# 57    183  TTerxQRfcFc  How to Build a Career in Tech: Tara Z. Manicsi...
# 58    366  MhvQVROFUEw  Amazon Alexa Skill Development Live Stream - D...
# 59    263  MhvQVROFUEw  Amazon Alexa Skill Development Live Stream - D...
#
#                                           description           publishedAt  \
# 0   This talk is an introduction to GraphQL with d...  2018-09-25T13:58:38Z
# 1   Get started with testing for the Front End. Le...  2018-11-01T15:00:00Z
# 2   Development isn't just for professionals, it's...  2018-12-04T20:11:15Z
# 3   Those of us who have worked in software develo...  2018-06-05T14:05:06Z
# 4   In this tutorial you will learn to build a cli...  2017-09-22T16:47:42Z
# 5   The internet is, without metaphor, just a bunc...  2018-11-30T14:26:36Z
# 6   Create basic CRUD routes with Node.js, Express...  2017-12-05T17:00:20Z
# 7   Create basic CRUD routes with Node.js, Express...  2017-12-05T17:00:20Z
# 8   In this presentation, we explore application d...  2018-06-07T15:02:33Z
# 9   Introduction to TypeScript. TypeScript is an o...  2018-05-18T16:30:04Z
# 10  What is DevOps really all about? Klaus Ita wil...  2018-07-09T19:43:48Z
# 11  Learn great tips for NOT becoming a senior dev...  2018-09-19T15:25:29Z
# 12  See a professional front-end developer at work...  2017-05-09T18:45:17Z
# 13  Learn about vector embeddings and how to use t...  2023-09-13T13:01:27Z
# 14  Learn how to build a basic social platform wit...  2018-08-28T17:52:43Z
# 15  Learn about how to become a developer and how ...  2018-09-21T12:09:28Z
# 16  React Router is commonly used to make differen...  2021-06-30T13:59:48Z
# 17  Learn how to create and deploy websites and In...  2023-11-01T13:23:55Z
# 18  Web applications don't talk with front-end and...  2018-09-24T14:40:17Z
# 19  Project 7 Day 7: Today we will review a pull r...  2019-03-22T13:22:36Z
# 20  Learn how to build performant web apps. A stor...  2018-07-16T18:04:38Z
# 21  Welcome to part 2 of a new series where I will...  2017-09-06T03:27:27Z
# 22  See a professional front-end developer at work...  2017-05-15T16:20:16Z
# 23  Ethan Arrowood, a Computer Science student fro...  2017-09-26T22:29:37Z
# 24  Ethan Arrowood, a Computer Science student fro...  2017-09-26T22:29:37Z
# 25  Create a real-time chat app using Firebase and...  2018-12-17T19:45:55Z
# 26  Flask is a micro web framework written in Pyth...  2019-05-28T12:43:15Z
# 27  This is an in-depth look at the Async/Await fe...  2019-01-10T19:16:48Z
# 28  A bunch of experienced developers will answer ...  2022-02-09T16:04:18Z
# 29  Learn about the Web Authentication API by buil...  2024-01-24T16:12:57Z
# 30  Learn how to build a complete chat application...  2018-06-05T16:30:01Z
# 31  Learn all about to node and npm!\n\nTalk by Lo...  2018-11-02T20:00:04Z
# 32  NGINX is open-source web server software used ...  2024-01-12T15:26:21Z
# 33  Welcome to part 5 of a new series where I will...  2017-09-09T19:46:46Z
# 34  Vue.js is an open-source JavaScript framework ...  2018-05-30T14:53:09Z
# 35  Learn about Kubernetes and what developers nee...  2018-11-09T15:42:02Z
# 36  Learn how to use Terraform and Infrastructure ...  2023-07-11T13:04:38Z
# 37  WebdriverIO is an E2E automation framework bui...  2021-04-02T12:52:12Z
# 38  Next.js comes with routing built in, but gives...  2017-05-22T18:58:14Z
# 39  freeCodeCamp.org has just launched a major upd...  2023-12-20T17:40:48Z
# 40  Distributed systems, Microservices and Web API...  2018-05-28T19:33:39Z
# 41  Project 5 Day 102: Today we will code with Rea...  2018-10-29T19:20:36Z
# 42  Project 5 Day 102: Today we will code with Rea...  2018-10-29T19:20:36Z
# 43  Project 5 Day 10: Today we are going to set up...  2017-12-11T20:17:46Z
# 44  Learn to develop an Amazon Alexa Skill in this...  2018-07-12T17:59:22Z
# 45  Welcome to part 1 of a new series where I will...  2017-09-03T04:50:41Z
# 46  Security is an important topic for developers ...  2018-05-22T14:26:10Z
# 47  Learn how to build an online book store from b...  2020-07-27T16:45:31Z
# 48  Learn the history and evolution of web develop...  2018-09-10T12:16:37Z
# 49  Learn the history and evolution of web develop...  2018-09-10T12:16:37Z
# 50  Project 5 Day 82: Today we will work creating ...  2018-07-05T20:38:48Z
# 51  Project 5 Day 82: Today we will work creating ...  2018-07-05T20:38:48Z
# 52  Learn to develop an Amazon Alexa Skill in this...  2018-07-13T18:03:26Z
# 53  Use AI to create a Discord chat bot that talks...  2021-08-26T13:30:35Z
